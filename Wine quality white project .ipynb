# %% [markdown]
# **White Wine Quality Analysis**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the Dataset**

# %%
White_wine = pd.read_csv("C:\\Users\\JESSICA\\Downloads\\winequality-white (1).csv")
White_wine
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %%
White_wine = pd.read_csv("C:\\Users\\JESSICA\\Downloads\\winequality-white (1).csv", delimiter=';', quotechar='"')
White_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# **Displaying First 10 Rows**

# %%
White_wine.head(10)
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 5  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 6  6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;...
# 7   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 8  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 9  8.1;0.22;0.43;1.5;0.044;28;129;0.9938;3.22;0.4...

# %% [markdown]
# **Displaying Last 10 Rows**

# %%
White_wine.tail(10)
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 4888  6.8;0.22;0.36;1.2;0.052;38;127;0.9933;3.04;0.5...
# 4889  4.9;0.235;0.27;11.75;0.03;34;118;0.9954;3.07;0...
# 4890  6.1;0.34;0.29;2.2;0.036;25;100;0.98938;3.06;0....
# 4891  5.7;0.21;0.32;0.9;0.038;38;121;0.99074;3.24;0....
# 4892  6.5;0.23;0.38;1.3;0.032;29;112;0.99298;3.29;0....
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...

# %% [markdown]
# **Info about the Dataset**

# %%
White_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  4898 non-null   object
# dtypes: object(1)
# memory usage: 38.4+ KB

# %%
White_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
White_wine['fixed acidity'].unique()
# Out:
# array([ 7.  ,  6.3 ,  8.1 ,  7.2 ,  6.2 ,  8.6 ,  7.9 ,  6.6 ,  8.3 ,
#         7.4 ,  6.5 ,  6.4 ,  6.8 ,  7.6 ,  6.9 ,  8.5 ,  5.8 ,  7.3 ,
#         6.7 ,  6.  ,  7.1 ,  6.1 ,  7.5 ,  9.8 ,  5.5 ,  5.9 ,  7.8 ,
#         5.7 ,  8.2 ,  5.6 ,  5.2 ,  8.4 , 10.2 ,  7.7 ,  5.3 ,  5.4 ,
#         9.1 ,  5.  ,  8.  , 10.  ,  5.1 ,  9.2 ,  9.  ,  8.8 ,  8.7 ,
#         4.8 , 10.3 ,  9.4 ,  9.6 ,  9.3 ,  8.9 ,  9.7 , 10.7 , 14.2 ,
#         9.9 ,  9.5 , 11.8 ,  4.6 ,  6.15,  4.5 ,  7.15,  6.45,  4.2 ,
#         4.9 ,  4.7 ,  3.8 ,  4.4 ,  3.9 ])

# %%
White_wine['citric acid'].unique()
# Out:
# array([0.36, 0.34, 0.4 , 0.32, 0.16, 0.43, 0.41, 0.37, 0.62, 0.38, 0.04,
#        0.48, 0.42, 0.14, 0.35, 0.39, 0.2 , 0.23, 0.26, 0.27, 0.31, 0.25,
#        0.29, 0.33, 0.59, 0.15, 0.24, 0.07, 0.03, 0.13, 0.28, 0.46, 0.3 ,
#        0.61, 0.63, 0.66, 0.54, 0.5 , 0.  , 0.47, 0.56, 0.22, 0.67, 0.18,
#        0.45, 0.44, 0.88, 0.21, 0.08, 0.49, 0.58, 0.7 , 0.6 , 0.51, 0.1 ,
#        0.19, 0.12, 0.09, 0.53, 0.02, 0.65, 0.17, 0.71, 0.06, 0.68, 0.72,
#        0.69, 1.66, 0.57, 0.05, 0.52, 1.  , 0.01, 0.74, 0.81, 0.55, 0.64,
#        0.73, 0.99, 0.78, 0.79, 0.82, 0.8 , 1.23, 0.86, 0.11, 0.91])

# %%
White_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
White_wine["quality"].value_counts()
# Out:
# quality
# 6    1788
# 5    1175
# 7     689
# 4     153
# 8     131
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# **Data Cleaning**

# %%
White_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
White_wine.duplicated().sum()
# Out:
# np.int64(937)

# %%
White_wine = White_wine.drop_duplicates()
White_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# **Exploration**

# %%
numeric_col= [col for col in White_wine.columns if White_wine[col].dtype!='0']
print("We have {} Numeric Columns :{}".format (len(numeric_col),numeric_col))
# Out:
# We have 12 Numeric Columns :['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
for cols in numeric_col:
    print(White_wine[cols].value_counts(normalize=True)*100)
    print('______________________________________________________')
# Out:
# fixed acidity
# 6.80     6.084322
# 6.60     6.008584
# 6.40     5.655138
# 6.90     4.822015
# 6.70     4.796768
#            ...
# 11.80    0.025246
# 7.15     0.025246
# 6.45     0.025246
# 3.80     0.025246
# 3.90     0.025246
# Name: proportion, Length: 68, dtype: float64
# ______________________________________________________
# volatile acidity
# 0.280    5.377430
# 0.240    5.251199
# 0.260    5.225953
# 0.250    4.519061
# 0.220    4.493815
#            ...
# 0.630    0.025246
# 0.690    0.025246
# 0.785    0.025246
# 0.405    0.025246
# 0.355    0.025246
# Name: proportion, Length: 125, dtype: float64
# ______________________________________________________
# citric acid
# 0.30    6.033830
# 0.28    5.554153
# 0.32    5.402676
# 0.34    4.569553
# 0.29    4.519061
#           ...
# 0.80    0.025246
# 1.23    0.025246
# 0.86    0.025246
# 0.11    0.025246
# 0.91    0.025246
# Name: proportion, Length: 87, dtype: float64
# ...

# %% [markdown]
# **Data Visualisation**

# %%
# Set style for plots
sns.set(style="whitegrid")

# %% [markdown]
# **Distribution of Wine Quality**

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='quality', data=White_wine, palette='viridis')
plt.title("Distribution of White Wine Quality Ratings")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\JESSICA\AppData\Local\Temp\ipykernel_12540\1546301033.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=White_wine, palette='viridis')

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(10,8))
sns.heatmap(White_wine.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap of White Wine Features")
plt.show()

# %% [markdown]
# **Alcohol vs Quality**

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='quality', y='alcohol', data=White_wine, palette='magma')
plt.title("Average Alcohol Content by Wine Quality")
plt.show()
# Out:
# C:\Users\JESSICA\AppData\Local\Temp\ipykernel_12540\1027259878.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality', y='alcohol', data=White_wine, palette='magma')

# %% [markdown]
# **Volatile Acidity vs Wine Quality**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='quality', y='volatile acidity', data=White_wine, palette='Set2')
plt.title("Volatile Acidity vs Wine Quality")
plt.show()
# Out:
# C:\Users\JESSICA\AppData\Local\Temp\ipykernel_12540\4151729590.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='volatile acidity', data=White_wine, palette='Set2')

# %% [markdown]
# **Citric Acid vs Quality**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='quality', y='citric acid', data=White_wine, palette='cool')
plt.title("Citric Acid vs Wine Quality")
plt.show()
# Out:
# C:\Users\JESSICA\AppData\Local\Temp\ipykernel_12540\299485075.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='citric acid', data=White_wine, palette='cool')

# %% [markdown]
# **Pairplot for Selected Features**

# %%
selected = ['alcohol', 'volatile acidity', 'citric acid', 'density', 'residual sugar', 'quality']
sns.pairplot(White_wine[selected], hue='quality', palette='husl')
plt.show()
