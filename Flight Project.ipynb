# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fp = pd.read_excel("C:\\Users\\JESSICA\\Downloads\\flight_price.xlsx")
fp
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fp.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
fp.tail(10)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 10673        Jet Airways      27/05/2019     Delhi      Cochin
# 10674        Jet Airways      12/03/2019  Banglore   New Delhi
# 10675          Air India       9/06/2019    Mumbai   Hyderabad
# 10676  Multiple carriers       1/05/2019     Delhi      Cochin
# 10677           SpiceJet      21/05/2019  Banglore       Delhi
# 10678           Air Asia       9/04/2019   Kolkata    Banglore
# 10679          Air India      27/04/2019   Kolkata    Banglore
# 10680        Jet Airways      27/04/2019  Banglore       Delhi
# 10681            Vistara      01/03/2019  Banglore   New Delhi
# 10682          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10674        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
# ...

# %%
fp.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
fp
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fp.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# **Data Cleaning**

# %%
fp['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
fp['Destination'].str.isnumeric().sum()
# Out:
# np.int64(0)

# %%
fp[fp['Source'].str.isnumeric()]
fp
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fp['Destination']=fp['Destination'].astype(str)

# %%
pd.crosstab(fp['Airline'],fp['Destination'])
# Out:
# Destination                        Banglore  Cochin  Delhi  Hyderabad  \
# Airline
# Air Asia                                150      80     71          0
# Air India                               512     747    120        136
# GoAir                                    25      76     69          0
# IndiGo                                  445     705    366        196
# Jet Airways                            1256    1586    370        219
# Jet Airways Business                      0       2      0          0
# Multiple carriers                         0    1196      0          0
# Multiple carriers Premium economy         0      13      0          0
# SpiceJet                                300      87    137        122
# Trujet                                    0       0      0          1
# Vistara                                 183      45    131         23
# Vistara Premium economy                   0       0      1          0
#
# ...

# %%
pd.crosstab(fp['Arrival_Time'],fp['Total_Stops'])
# Out:
# Total_Stops   1 stop  2 stops  3 stops  4 stops  non-stop
# Arrival_Time
# 00:05 02 Apr       0        0        0        0         2
# 00:05 02 Jun       0        0        0        0         2
# 00:05 02 Mar       0        0        0        0         2
# 00:05 02 May       0        0        0        0         1
# 00:05 04 Apr       0        0        0        0         2
# ...              ...      ...      ...      ...       ...
# 23:40              3        0        0        0        25
# 23:45             17        2        0        0         0
# 23:50              2        0        0        0        25
# 23:55              6        2        1        0        34
# 23:55 02 Mar       0        2        0        0         0
#
# [1343 rows x 5 columns]

# %%
sns.heatmap(pd.crosstab(fp['Airline'],fp['Destination']))
# Out:
# <Axes: xlabel='Destination', ylabel='Airline'>

# %%
(fp.groupby('Airline')['Price'].mean()*100).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Price'>

# %%
pd.crosstab(fp['Date_of_Journey'],fp['Destination'])
# Out:
# Destination      Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# Date_of_Journey
# 01/03/2019              0       0      0          0        0        152
# 03/03/2019              0       0      0          0        0         97
# 06/03/2019              0       0      0          0        0         95
# 09/03/2019              0       0      0          0        0        102
# 1/03/2019              15       9      0         13       10          0
# 1/04/2019             176      24     40         17        0          0
# 1/05/2019             183      17     42         21       14          0
# 1/06/2019              18     242     47         21       14          0
# 12/03/2019             10       0      0         28        8         96
# 12/04/2019             21       0     42          0        0          0
# 12/05/2019            167       9     48         23       12          0
# 12/06/2019            179     241     44         19       10          0
# ...

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.clustermap(pd.crosstab(fp['Airline'],fp['Route']))

# %%
sns.pairplot(data = fp)

# %%
sns.lineplot(x=fp['Airline'],y=fp['Source'])
# Out:
# <Axes: xlabel='Airline', ylabel='Source'>

# %%
print((fp[fp['Airline']==0]['Destination'].mean()))
print((fp[fp['Airline']==1]['Destination'].mean()))
# Out:
# nan
# nan

# %%
pd.crosstab(fp['Airline'],fp['Destination']).plot(kind='bar')
# Out:
# <Axes: xlabel='Airline'>

# %%
fp['Destination'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Destination'>

# %%
fp['Arrival_Time']=fp['Arrival_Time'].apply(lambda x:x.split(' ')[0])

# %%
fp['Arrival_hour']=fp['Arrival_Time'].str.split('.').str[0]
fp['Arrival_min']=fp['Arrival_Time'].str.split('.').str[0]

# %%
fp.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20        01:10   2h 50m    non-stop         No info   3897
# 1    05:50        13:15   7h 25m     2 stops         No info   7662
#
#   Arrival_hour Arrival_min
# 0        01:10       01:10
# 1        13:15       13:15
